# %%
import pandas as pd
df = pd.read_json('data/2021-11-25-14-55-43.json')
df
# Out:
#      question_id                                             title  domain  \
# 0      315442246                        总听大家说 319 国道，那么 219 国道怎么样？  100025
# 1      315442246                        总听大家说 319 国道，那么 219 国道怎么样？  100028
# 2       36951304                                      恋爱之后让你明白了什么？       0
# 3       36951304                                      恋爱之后让你明白了什么？  100013
# 4      431681557                                    做独立游戏制作人真的很难吗？  100021
# ..           ...                                               ...     ...
# 595    501458628  律师表示，严格限制老婆花钱，是限制其社会活动的自由，也是家暴，还有哪些家暴冷知识或误区值得了解？  100007
# 596    501458628  律师表示，严格限制老婆花钱，是限制其社会活动的自由，也是家暴，还有哪些家暴冷知识或误区值得了解？       0
# 597    501458628  律师表示，严格限制老婆花钱，是限制其社会活动的自由，也是家暴，还有哪些家暴冷知识或误区值得了解？  100013
# 598     65141672                                     有哪些好喝的冲剂固体饮料？       0
# 599     65141672                                     有哪些好喝的冲剂固体饮料？  100027
#
#         created        updated_time               topics  new_pv  \
# ...

# %%
df['value'] = df['new_pv'] / df['answer_num']
df.sort_values(by=['value'], ascending=False)
# Out:
#      question_id                                              title  domain  \
# 454    500998306  如何评价华为调侃美国「黑五」，所有美国在售手机享 100% 折扣，随后又表示他们不能在美国卖...  100001
# 455    500998306  如何评价华为调侃美国「黑五」，所有美国在售手机享 100% 折扣，随后又表示他们不能在美国卖...  100002
# 543    501297605                              如何看待岸田文雄正式宣布释放日本石油储备？  100012
# 386    500795055         女孩增重 20 斤圆梦火箭军，一个好兵对身体素质要求有多高？军人的体能素质有多厉害？  100008
# 524    501241765                  iPhone 15 概念设计图曝光，15 可能做出哪些升级和改变？  100021
# ..           ...                                                ...     ...
# 8      480234319                                如何评价严浩翔的新歌《尾号6208》?  100020
# 88     498986311                                  如何评价央视网评隔离宠物狗被扑杀?  100023
# 111    499205345                             抑郁到想离开这个世界，控制不住自己该怎么办？  100014
# 404    500850446  你好陌生人，今天是我生日，如过去很多个生日那样，自己陪自己。身边没有朋友没有家人，可以跟我说...  100017
# 91     499017701  陌生人你好，我是一名高二学生，我现在对我的前途很迷茫，想要刻苦学习，但总是学不进去，我是不是...  100013
#
# ...

# %%
df[df.domain.isin([100001, 100002, 100003])].sort_values(by=['value'], ascending=False).head(n=10)
# Out:
#      question_id                                              title  domain  \
# 455    500998306  如何评价华为调侃美国「黑五」，所有美国在售手机享 100% 折扣，随后又表示他们不能在美国卖...  100002
# 454    500998306  如何评价华为调侃美国「黑五」，所有美国在售手机享 100% 折扣，随后又表示他们不能在美国卖...  100001
# 523    501241765                  iPhone 15 概念设计图曝光，15 可能做出哪些升级和改变？  100001
# 461    501028570        如何看待最近头部厂商接连发力自拍旗舰？OPPO 首发的 IMX709 传感器实力如何？  100002
# 460    501028570        如何看待最近头部厂商接连发力自拍旗舰？OPPO 首发的 IMX709 传感器实力如何？  100001
# 427    500928888            如何看待网易云音乐将于 12 月 2 日挂牌上市？这对在线音乐市场有什么影响？  100003
# 450    500976135  如何看待 Facebook 员工对领导层失去信心，愿长期留任者不足一半?你愿意长留自己现在的...  100003
# 280    500334548                            如何评价NVIDIA RTX 4090 显卡？  100001
# 459    501025255                  Rust 编程语言审核团队宣布辞职，发生了什么？将会带来哪些影响？  100003
# 443    500954715  如何看待高通宣布骁龙将成为独立品牌，并采用全新的命名规则？全新一代骁龙移动平台即将来临你有哪...  100002
#
#         created        updated_time  \
# 455  1637649086 2021-11-23 06:31:26
# 454  1637649086 2021-11-23 06:31:26
# ...
